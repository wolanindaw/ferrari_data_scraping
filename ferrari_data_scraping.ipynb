# %%
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.supercars.net/blog/all-brands/ferrari/ferrari-model-list/'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'lxml')

# %%
models = soup.find_all('div', class_='block-html-content clearfix link-color-wrap')

# %%
for model in models[:28:2]:
    names = model.find_all('a')
    for name in names:
        print(name.text)
        print(name['href'])
# Out:
# Ferrari 812 GTS
# https://www.supercars.net/blog/ferrari-812-gts/
# Ferrari SF90 Stradale
# https://www.supercars.net/blog/category/brand/ferrari/ferrari-supercars/ferrari-sf90-stradale/
# Ferrari SF90 Spider
# https://www.supercars.net/blog/category/brand/ferrari/ferrari-supercars/ferrari-sf90-spider/
# Ferrari 296 GTB
# https://www.supercars.net/blog/ferrari-296-gtb-an-in-depth-look/
# Ferrari 296 GTS
# https://www.supercars.net/blog/the-new-ferrari-296-gts/
# Ferrari F8 Tributo
# https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-f8-tributo/
# Ferrari F8 Spider
# https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-f8-tributo/ferrari-f8-tributo-spider/
# Ferrari Roma
# https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-roma/
# Ferrari Portofino M
# https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-portofino/ferrari-portofino-m/
# Ferrari 812 Competizione
# https://www.supercars.net/blog/2022-ferrari-812-competizione-competizione-a-an-in-depth-look/
# Ferrari 812 Competizione A
# https://www.supercars.net/blog/2022-ferrari-812-competizione-competizione-a-an-in-depth-look/
# Ferrari Daytona SP3
# https://www.supercars.net/blog/ferrari-daytona-sp3-a-closer-look/
# Ferrari Monza SP1
# https://www.supercars.net/blog/category/brand/ferrari/ferrari-supercars/ferrari-monza/
# Ferrari Monza SP2
# https://www.supercars.net/blog/category/brand/ferrari/ferrari-supercars/ferrari-monza/

# %%
for item in models[:28]:
    li_tags = item.find_all('li')
    for li_tag in li_tags:
        print(li_tag)
# Out:
# <li><p><strong>Base price: </strong>US$401,000</p></li>
# <li><p><strong>Engine: </strong>6.2L naturally aspirated V12</p></li>
# <li><p><strong>Power: </strong>789 hp @ 8900 rpm</p></li>
# <li><p><strong>Torque:</strong> 530 lb-ft @ 7000 rpm</p></li>
# <li><p><strong>0-60 mph:</strong> 2.9 s</p></li>
# <li><p><strong>0-124 mph: </strong>8.3 s</p></li>
# <li><p><br/></p><p><strong>Top Speed: </strong>211 mph</p></li>
# <li><p><strong>Base price: </strong>US$507,000</p></li>
# <li><p><strong>Engine: </strong>4.0L TT V8 + 3 electric</p></li>
# <li><p><strong>Power: </strong>989 hp (combined)</p></li>
# <li><p><strong>Torque: </strong>590 lb-ft</p></li>
# <li><p><strong>0-60 mph:</strong> 2.5 s</p></li>
# <li><p><strong>0-124 mph: </strong>6.7 s</p></li>
# <li><p><strong>Top Speed: </strong>211 mph</p></li>
# <li><p><strong>Base price: </strong>US$557,000</p></li>
# <li><p><strong>Engine: </strong>4.0L TT V8 + 3 electric</p></li>
# <li><p><strong>Power: </strong>989 hp (combined)</p></li>
# <li><p><strong>Torque: </strong>590 lb-ft</p></li>
# <li><p><strong>0-60 mph: </strong>2.5 s</p></li>
# <li><p><strong>0-124 mph:</strong> 6.7 s</p></li>
# <li><p><strong>Top Speed: </strong>211 mph</p></li>
# <li><p><strong>Base price: </strong>US$322,986</p></li>
# <li><p><strong>Engine: </strong>2.9L TT V6 + Electric Motor</p></li>
# <li><p><strong>Power: </strong>819 hp (combined)</p></li>
# <li><p><strong>Torque: </strong>546 lb-ft</p></li>
# <li><p><strong>0-60 mph: </strong>2.9 s</p></li>
# <li><p><strong>0-124 mph:</strong> 7.3 s</p></li>
# <li><p><strong>Top Speed: </strong>205 mph</p></li>
# <li><p><strong>Base price: ≈ </strong>US$340,000</p></li>
# <li><p><strong>Engine: </strong>2.9L TT V6 + Electric Motor</p></li>
# <li><p><strong>Power: </strong>819 hp (combined)</p></li>
# <li><p><strong>Torque: </strong>546 lb-ft</p></li>
# <li><p><strong>0-60 mph: </strong>2.9 s</p></li>
# <li><p><strong>0-124 mph:</strong> 7.6 s</p></li>
# <li><p><strong>Top Speed: </strong>205 mph</p></li>
# <li><p><strong>Base price: </strong>US$276,000</p></li>
# <li><p><strong>Engine: </strong>3.9L twin-turbo V8</p></li>
# <li><p><strong>Power: </strong>710 hp @ 8000 rpm</p></li>
# <li><p><strong>Torque: </strong>568 lb-ft @ 3250 rpm</p></li>
# <li><p><strong>0-60 mph:</strong> 2.9 s</p></li>
# <li><p><strong>0-124 mph:</strong> 7.8 s</p></li>
# <li><p><strong>Top Speed: </strong>211 mph</p></li>
# <li><p><strong>Base price: </strong>US$274,000</p></li>
# <li><p><strong>Engine: </strong>3.9L twin-turbo V8</p></li>
# <li><p><strong>Power: </strong>710 hp @ 8000 rpm</p></li>
# <li><p><strong>Torque: </strong>568 lb-ft @ 3250 rpm</p></li>
# <li><p><strong>0-60 mph: </strong>2.9 s</p></li>
# <li><p><strong>0-124 mph: </strong>7.8 s</p></li>
# <li><p><strong>Top Speed: </strong>211 mph</p></li>
# <li><p><strong>Base price: </strong>US$222,630</p></li>
# <li><p><strong>Engine: </strong>3.9L twin-turbo V8</p></li>
# <li><p><strong>Power: </strong>612 hp @ 7500 rom</p></li>
# <li><p><strong>Torque:</strong> 560 lb-ft @ 3000 rpm</p></li>
# <li><p><strong>0-60 mph: </strong>3.4 s</p></li>
# <li><p><strong>0-124 mph: </strong>9.3 s</p></li>
# <li><p><strong>Top Speed: </strong>199 mph</p></li>
# <li><p><strong>Base price: </strong>US$245,000</p></li>
# <li><p><strong>Engine:</strong> 3.9L twin-turbo V8</p></li>
# <li><p><strong>Power: </strong>612 hp @ 7,500 rpm</p></li>
# <li><p><strong>Torque: </strong>560 lb-ft @ 3000 rpm</p></li>
# <li><p><strong>0-60 mph: </strong>3.4 s</p></li>
# <li><p><strong>0-124 mph:</strong> 9.3 s</p></li>
# <li><p><strong>Top Speed: </strong>199 mph</p></li>
# <li><p><strong>Base price: </strong>US$601,570</p></li>
# <li><p><strong>Engine: </strong>6.5L naturally aspirated V12</p></li>
# <li><p><strong>Power: </strong>819 hp @ 9,250 rpm</p></li>
# <li><p><strong>Torque: </strong>510 lb-ft @ 7,000 rpm</p></li>
# <li><p><strong>0-60 mph: </strong>2.6 s</p></li>
# <li><p><strong>0-124 mph:</strong> 7.0 s</p></li>
# <li><p><strong>Top Speed: </strong>212 mph</p></li>
# <li><p><strong>Base price: </strong>US$672,000</p></li>
# <li><p><strong>Engine: </strong>6.5L naturally aspirated V12</p></li>
# <li><p><strong>Power: </strong>819 hp @ 9,250 rpm</p></li>
# <li><p><strong>Torque: </strong>510 lb-ft @ 7,000 rpm</p></li>
# <li><p><strong>0-60 mph: </strong>2.85 s</p></li>
# <li><p><strong>0-124 mph:</strong> 7.5 s</p></li>
# <li><p><strong>Top Speed: </strong>212 mph</p></li>
# <li><p><strong>Base price: </strong>US$2,250,000</p></li>
# <li><p><strong>Engine: </strong>6.5L naturally aspirated V12</p></li>
# <li><p><strong>Power: </strong>829 hp @ 9,250 rpm</p></li>
# <li><p><strong>Torque: </strong>514 lb-ft @ 7,000 rpm</p></li>
# <li><p><strong>0-60 mph: </strong>2.86 s</p></li>
# <li><p><strong>0-124 mph:</strong> 7.4 s</p></li>
# <li><p><strong>Top Speed: </strong>211 mph</p></li>
# <li><p><strong>Base price: </strong>&gt;US$1,800,000</p></li>
# <li><p><strong>Engine:</strong> 6.5 L nat asp V12</p></li>
# <li><p><strong>Power: </strong>810 bhp @ 8500 rpm</p></li>
# <li><p><strong>Torque: </strong>530 lb-ft @ 7000 rpm</p></li>
# <li><p><strong>0-60 mph: </strong>&lt; 3 sec (est)</p></li>
# <li><p><strong>0-100 mph: </strong>&lt; 8 sec (est)</p></li>
# <li><p><strong>Top Speed: </strong>186 mph</p></li>
# <li><p><strong>Base price: </strong>&gt;US$1,800,000</p></li>
# <li><p><strong>Engine: </strong>6.5 L nat asp V12</p></li>
# <li><p><strong>Power: </strong>810 bhp @ 8500 rpm</p></li>
# <li><p><strong>Torque: </strong>530 lb-ft @ 7000 rpm</p></li>
# <li><p><strong>0-60 mph: </strong>&lt; 3 sec (est)</p></li>
# <li><p><strong>0-100 mph: </strong>&lt; 8 sec (est)</p></li>
# <li><p><strong>Top Speed:</strong> 186 mph</p></li>

# %%
current_model_names = []
current_model_links = []

for model in models[:28:2]:
    names = model.find_all('a')
    for name in names:
        current_model_names.append(name.text)
        current_model_links.append(name['href'])

# %%
print(current_model_names)
print(current_model_links)
# Out:
# ['Ferrari 812 GTS', 'Ferrari SF90 Stradale', 'Ferrari SF90 Spider', 'Ferrari 296 GTB', 'Ferrari 296 GTS', 'Ferrari F8 Tributo', 'Ferrari F8 Spider', 'Ferrari Roma', 'Ferrari Portofino M', 'Ferrari 812 Competizione', 'Ferrari 812 Competizione A', 'Ferrari Daytona SP3', 'Ferrari Monza SP1', 'Ferrari Monza SP2']
# ['https://www.supercars.net/blog/ferrari-812-gts/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-supercars/ferrari-sf90-stradale/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-supercars/ferrari-sf90-spider/', 'https://www.supercars.net/blog/ferrari-296-gtb-an-in-depth-look/', 'https://www.supercars.net/blog/the-new-ferrari-296-gts/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-f8-tributo/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-f8-tributo/ferrari-f8-tributo-spider/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-roma/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-portofino/ferrari-portofino-m/', 'https://www.supercars.net/blog/2022-ferrari-812-competizione-competizione-a-an-in-depth-look/', 'https://www.supercars.net/blog/2022-ferrari-812-competizione-competizione-a-an-in-depth-look/', 'https://www.supercars.net/blog/ferrari-daytona-sp3-a-closer-look/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-supercars/ferrari-monza/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-supercars/ferrari-monza/']

# %%
legacy_model_names = []
legacy_model_links = []

for model in models[28::2]:
    names = model.find_all('a')
    for name in names:
        legacy_model_names.append(name.text)
        legacy_model_links.append(name['href'])

# %%
print(legacy_model_names)
print(legacy_model_links)
# Out:
# ['Ferrari 166 Inter', 'Ferrari 195 Inter', 'Ferrari 212 Inter', 'Ferrari 212 Export', 'Ferrari 342 America', 'Ferrari 375 America', 'Ferrari 410 Superamerica I', 'Ferrari 410 Superamerica II', 'Ferrari 410 Superamerica III', 'Ferrari 250 Europa', 'Ferrari 250 Europa GT', 'Ferrari 250 GT Coupé (Boano)', 'Ferrari 250 GT Coupé (Ellena)', 'Ferrari 250 GT Coupé', 'Ferrari 250 GT Berlinetta (Tdf)', 'Ferrari 250 GT Cabriolet Series I', 'Ferrari 250 GT California LWB', '250 GT Cabriolet Series II', 'Ferrari 250 GT California SWB', 'Ferrari 250 GT 2+2 (GT/E)', 'Ferrari 250 GT Berlinetta "Interim', 'Ferrari 250 GT SWB Berlinetta ‘Lusso’', 'Ferrari 250 GT Berlinetta Lusso', 'Ferrari 250 GTO', 'Ferrari 400 Superamerica', 'Ferrari 400 Superamerica II', 'Ferrari 275 GTB', 'Ferrari 275 GTS', 'Ferrari 330 America', 'Ferrari 330 GT 2+2 I', 'Ferrari 500 Superfast', 'Ferrari 275 GTB/4', 'Ferrari 275 GTB/4S NART Spider', 'Ferrari 330 GT 2+2 II', 'Ferrari 330 GTC', 'Ferrari 330 GTS', 'Ferrari 365 California', 'Ferrari 365 GT 2+2', 'Ferrari 365 GTB/4 (Daytona)', 'Ferrari 365 GTC', 'Ferrari 365 GTS', 'Ferrari 365 GTC4', 'Ferrari 365 GT4 2+2', 'Ferrari 400 Auto', 'Ferrari 400 GT', 'Ferrari 400 Auto i', 'Ferrari 400 GTi', 'Ferrari 412', 'Dino 206 GT', 'Dino 246 GT', 'Dino 246 GTS', 'Dino 308 GT4', 'Ferrari 308 GT4', 'Ferrari 208 GT4', 'Ferrari 365 GT4 BB', 'Ferrari 512 BB', 'Ferrari 512 BBi', 'Ferrari 308 GTB Vetroresina', 'Ferrari 308 GTB', 'Ferrari 308 GTS', 'Ferrari 208 GTB', 'Ferrari 208 GTS', 'Ferrari 308 GTBi', 'Ferrari 308 GTSi', 'Ferrari 208 GTB Turbo', 'Ferrari 208 GTS Turbo', 'Ferrari 308 GTB Quattrovalvole', 'Ferrari 308 GTS Quattrovalvole', 'Ferrari 288 GTO', 'Ferrari 328 GTB', 'Ferrari 328 GTB', 'Ferrari GTB Turbo', 'Ferrari GTS Turbo', 'Ferrari Mondial 8', 'Ferrari Mondial QV', 'Ferrari Mondial Cabriolet', 'Ferrari 3.2 Mondial', 'Ferrari 3.2 Mondial Cabriolet', 'Ferrari Mondial T', 'Ferrari Mondial T Cabriolet', 'Ferrari Testarossa', 'Ferrari 512 TR', 'Ferrari F512 M', 'Ferrari 348 TB', 'Ferrari 348 TS', 'Ferrari 348 GTB', 'Ferrari 348 GTS', 'Ferrari 348 Spider', '348 Serie Speciale', 'Ferrari F355', 'Ferrari F355 GTS', 'Ferrari F355 Spider', 'Ferrari F355 F1', 'Ferrari F355 F1 GTS', 'Ferrari F355 F1 Spider', 'Ferrari 456 GT', 'Ferrari 456 GTA', 'Ferrari 456M GT', 'Ferrari 456M GTA', 'Ferrari 456M GT Scaglietti', 'Ferrari 550 Maranello', 'Ferrari 550 Barchetta', 'Ferrari 575M Maranello', 'Ferrari 612 Scaglietti', 'Ferrari 360 Modena', 'Ferrari 360 Spider', 'Ferrari Challenge Stradale', 'Ferrari F430', 'Ferrari F430 Spider', 'Ferrari 430 Scuderia', 'Ferrari Scuderia Spider 16M', 'Ferrari 599 GTB', 'Ferrari 599 GTO', 'Ferrari SA APERTA', 'Ferrari California', 'Ferrari California 30', 'Ferrari California T', 'Ferrari 458 Italia', 'Ferrari 458 Spider', 'Ferrari 458 Speciale', 'Ferrari 458 Speciale A', 'Ferrari 458 Italia China Edition', 'Ferrari FF', 'Ferrari GTC4Lusso', 'Ferrari GTC4Lusso T', 'Ferrari F12berlinetta', 'Ferrari F12tdf', 'Ferrari 488 GTB', 'Ferrari 488 Spider', 'Ferrari 488 Pista', 'Ferrari 488 Pista Spider', 'Ferrari 488 Pista Piloti', 'Ferrari Portofino', 'Ferrari 812 Superfast', 'Ferrari 812 GTS', 'Ferrari 250 GTO', 'Ferrari 288 GTO', 'Ferrari F40', 'Ferrari F50', 'Ferrari Enzo', 'Ferrari LaFerrari']
# ['https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-166-inter/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-195-inter', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-212-inter', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-sports-prototypes/212-export/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-america/ferrari-342-america/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-375-america/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-america/ferrari-410-superamerica/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-america/ferrari-410-superamerica/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-america/ferrari-410-superamerica/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-250-europa', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-europa-gt/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-boano-and-ellena/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-boano-and-ellena/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-coupe/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250-berlinetta/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-cabriolet/ferrari-250-gt-cabriolet-pininfarina-series-i/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-california-spyder-lwb/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-cabriolet/ferrari-250-gt-cabriolet-pininfarina-series-ii/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-california-spyder-swb/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-22/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-250-gt-berlinetta-interim/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-berlinetta-swb/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-250/ferrari-250-gt-berlinetta-lusso/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-250-gto', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-america/ferrari-400-superamerica/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-america/ferrari-400-superamerica/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-275/ferrari-275-gtb-ferrari-275/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-275-gts', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-330/ferrari-330-america/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-330/ferrari-330-gt-22/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-america/ferrari-500-superfast/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-275-gtb-4', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-275/ferrari-275-gts-4-nart-spyder/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-330/ferrari-330-gt-22/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-330-gtc', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-330-gts/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-road-cars/ferrari-365/ferrari-365-california/', 'https://www.supercars.net/blog/category/brand/ferrari/ferrari-365-gt-22', 'https://www.supercars.n ...

# %%
import pandas as pd

# %%
for item in models[0]:
    li_tags = item.find_all('li')
    current_model_data_columns = [li_tag.text.split(':')[0] for li_tag in li_tags]
    print(current_model_data_columns)
# Out:
# []
# ['Base price', 'Engine', 'Power', 'Torque', '0-60 mph', '0-124 mph', 'Top Speed']

# %%
df1 = pd.DataFrame(columns = current_model_data_columns)
df1
# Out:
# Empty DataFrame
# Columns: [Base price, Engine, Power, Torque, 0-60 mph, 0-124 mph, Top Speed]
# Index: []

# %%
for item in models[:28:2]:
    li_tags = item.find_all('li')
    individual_row_data = [li_tag.text.split(':')[-1].strip() for li_tag in li_tags]
    #print(individual_row_data)
    length = len(df1)
    df1.loc[length] = individual_row_data

# %%
df1
# Out:
#        Base price                        Engine               Power  \
# 0      US$401,000  6.2L naturally aspirated V12   789 hp @ 8900 rpm
# 1      US$507,000       4.0L TT V8 + 3 electric   989 hp (combined)
# 2      US$557,000       4.0L TT V8 + 3 electric   989 hp (combined)
# 3      US$322,986   2.9L TT V6 + Electric Motor   819 hp (combined)
# 4    ≈ US$340,000   2.9L TT V6 + Electric Motor   819 hp (combined)
# 5      US$276,000            3.9L twin-turbo V8   710 hp @ 8000 rpm
# 6      US$274,000            3.9L twin-turbo V8   710 hp @ 8000 rpm
# 7      US$222,630            3.9L twin-turbo V8   612 hp @ 7500 rom
# 8      US$245,000            3.9L twin-turbo V8  612 hp @ 7,500 rpm
# 9      US$601,570  6.5L naturally aspirated V12  819 hp @ 9,250 rpm
# 10     US$672,000  6.5L naturally aspirated V12  819 hp @ 9,250 rpm
# 11   US$2,250,000  6.5L naturally aspirated V12  829 hp @ 9,250 rpm
# 12  >US$1,800,000             6.5 L nat asp V12  810 bhp @ 8500 rpm
# 13  >US$1,800,000             6.5 L nat asp V12  810 bhp @ 8500 rpm
#
#                    Torque       0-60 mph      0-124 mph Top Speed
# 0    530 lb-ft @ 7000 rpm          2.9 s          8.3 s   211 mph
# 1               590 lb-ft          2.5 s          6.7 s   211 mph
# 2               590 lb-ft          2.5 s          6.7 s   211 mph
# 3               546 lb-ft          2.9 s          7.3 s   205 mph
# 4               546 lb-ft          2.9 s          7.6 s   205 mph
# 5    568 lb-ft @ 3250 rpm          2.9 s          7.8 s   211 mph
# 6    568 lb-ft @ 3250 rpm          2.9 s          7.8 s   211 mph
# 7    560 lb-ft @ 3000 rpm          3.4 s          9.3 s   199 mph
# 8    560 lb-ft @ 3000 rpm          3.4 s          9.3 s   199 mph
# 9   510 lb-ft @ 7,000 rpm          2.6 s          7.0 s   212 mph
# 10  510 lb-ft @ 7,000 rpm         2.85 s          7.5 s   212 mph
# 11  514 lb-ft @ 7,000 rpm         2.86 s          7.4 s   211 mph
# 12   530 lb-ft @ 7000 rpm  < 3 sec (est)  < 8 sec (est)   186 mph
# 13   530 lb-ft @ 7000 rpm  < 3 sec (est)  < 8 sec (est)   186 mph

# %%
df1.insert(0, "Model Name", current_model_names, True)
df1.insert(1, "More Info", current_model_links, True)

# %%
df1
# Out:
#                     Model Name  \
# 0              Ferrari 812 GTS
# 1        Ferrari SF90 Stradale
# 2          Ferrari SF90 Spider
# 3              Ferrari 296 GTB
# 4              Ferrari 296 GTS
# 5           Ferrari F8 Tributo
# 6            Ferrari F8 Spider
# 7                 Ferrari Roma
# 8          Ferrari Portofino M
# 9     Ferrari 812 Competizione
# 10  Ferrari 812 Competizione A
# 11         Ferrari Daytona SP3
# 12           Ferrari Monza SP1
# 13           Ferrari Monza SP2
#
#                                             More Info     Base price  \
# 0     https://www.supercars.net/blog/ferrari-812-gts/     US$401,000
# 1   https://www.supercars.net/blog/category/brand/...     US$507,000
# 2   https://www.supercars.net/blog/category/brand/...     US$557,000
# 3   https://www.supercars.net/blog/ferrari-296-gtb...     US$322,986
# 4   https://www.supercars.net/blog/the-new-ferrari...   ≈ US$340,000
# 5   https://www.supercars.net/blog/category/brand/...     US$276,000
# 6   https://www.supercars.net/blog/category/brand/...     US$274,000
# 7   https://www.supercars.net/blog/category/brand/...     US$222,630
# 8   https://www.supercars.net/blog/category/brand/...     US$245,000
# 9   https://www.supercars.net/blog/2022-ferrari-81...     US$601,570
# 10  https://www.supercars.net/blog/2022-ferrari-81...     US$672,000
# 11  https://www.supercars.net/blog/ferrari-daytona...   US$2,250,000
# 12  https://www.supercars.net/blog/category/brand/...  >US$1,800,000
# 13  https://www.supercars.net/blog/category/brand/...  >US$1,800,000
#
#                           Engine               Power                 Torque  \
# 0   6.2L naturally aspirated V12   789 hp @ 8900 rpm   530 lb-ft @ 7000 rpm
# 1        4.0L TT V8 + 3 electric   989 hp (combined)              590 lb-ft
# 2        4.0L TT V8 + 3 electric   989 hp (combined)              590 lb-ft
# 3    2.9L TT V6 + Electric Motor   819 hp (combined)              546 lb-ft
# 4    2.9L TT V6 + Electric Motor   819 hp (combined)              546 lb-ft
# 5             3.9L twin-turbo V8   710 hp @ 8000 rpm   568 lb-ft @ 3250 rpm
# 6             3.9L twin-turbo V8   710 hp @ 8000 rpm   568 lb-ft @ 3250 rpm
# 7             3.9L twin-turbo V8   612 hp @ 7500 rom   560 lb-ft @ 3000 rpm
# 8             3.9L twin-turbo V8  612 hp @ 7,500 rpm   560 lb-ft @ 3000 rpm
# 9   6.5L naturally aspirated V12  819 hp @ 9,250 rpm  510 lb-ft @ 7,000 rpm
# 10  6.5L naturally aspirated V12  819 hp @ 9,250 rpm  510 lb-ft @ 7,000 rpm
# 11  6.5L naturally aspirated V12  829 hp @ 9,250 rpm  514 lb-ft @ 7,000 rpm
# 12             6.5 L nat asp V12  810 bhp @ 8500 rpm   530 lb-ft @ 7000 rpm
# 13             6.5 L nat asp V12  810 bhp @ 8500 rpm   530 lb-ft @ 7000 rpm
#
#          0-60 mph      0-124 mph Top Speed
# 0           2.9 s          8.3 s   211 mph
# 1           2.5 s          6.7 s   211 mph
# 2           2.5 s          6.7 s   211 mph
# 3           2.9 s          7.3 s   205 mph
# 4           2.9 s          7.6 s   205 mph
# 5           2.9 s          7.8 s   211 mph
# 6           2.9 s          7.8 s   211 mph
# 7           3.4 s          9.3 s   199 mph
# 8           3.4 s          9.3 s   199 mph
# 9           2.6 s          7.0 s   212 mph
# 10         2.85 s          7.5 s   212 mph
# 11         2.86 s          7.4 s   211 mph
# 12  < 3 sec (est)  < 8 sec (est)   186 mph
# 13  < 3 sec (est)  < 8 sec (est)   186 mph

# %%
df1.to_csv(r'C:\Users\dawid\Python Outputs\current_ferrari_models.csv')

# %%
for item in models[28]:
    li_tags = item.find_all('li')
    legacy_model_data_columns = [li_tag.text.split(':')[0] for li_tag in li_tags]
    print(legacy_model_data_columns)
# Out:
# []
# ['Years', 'Production', 'Engine', 'Power', 'Torque', '0-60 mph', 'Top Speed']

# %%
df2 = pd.DataFrame(columns = legacy_model_data_columns)
df2
# Out:
# Empty DataFrame
# Columns: [Years, Production, Engine, Power, Torque, 0-60 mph, Top Speed]
# Index: []

# %%
slice1 = models[28:110:2]
slice2 = models[112:134:2]
slice3 = models[136:222:2]
slice4 = models[224:240:2]
slice5 = models[242::2]

for item in slice1 + slice2 + slice3 + slice4 + slice5:
    li_tags = item.find_all('li')
    individual_row_data2 = [li_tag.text.split(':')[-1].strip() for li_tag in li_tags]
    print(individual_row_data2)
    
    length2 = len(df2)
    df2.loc[length2] = individual_row_data2
# Out:
# ['1948 - 1950', '38 units', '2.0 L Colombo V12', '110 bhp @ 6,000 rpm', 'N/A', 'N/A', '106 mph']
# ['1950 - 1951', '28 units', '2.3 L Colombo V12', '130 bhp @ 6000 rpm', 'N/A', 'N/A', '112 mph']
# ['1951 - 1952', '82 units', '2.6 L Colombo V12', '150 bhp @ 6500 rpm', 'N/A', 'N/A', '112 mph']
# ['1951 - 1952', '27 units', '2.6 L Colombo V12', '150 bhp @ 6500 rpm', 'N/A', '~9.0 seconds', '115 mph']
# ['1952', '23 units', '4.1 L Lampredi V12', '200 bhp @ 5000 rpm', 'N/A', 'N/A', '116 mph']
# ['1953 - 1954', '12 units', '4.5 L Lampredi V12', '300 bhp @ 6300 rpm', 'N/A', 'N/A', '155 mph']
# ['1955', '35 (410 total)', '5.0 L Lampredi V12', '340 bhp @ 6000 rpm', 'N/A', '~ 6.0 seconds', '150 mph']
# ['1956 - 1957', '35 (410 total)', '5.0 L Lampredi V12', '360 bhp @ 7600 rpm', 'N/A', '~ 6.0 seconds', '150 mph']
# ['1958 - 1959', '35 (410 total)', '5.0 L Lampredi V12', '380 bhp @ 7600 rpm', 'N/A', '~ 6.0 seconds', '150 mph']
# ['1953', '21', '3.0 L Lampredi V12', '200 bhp @ 6,300 rpm', 'N/A', '5.9 seconds', '135 mph']
# ['1954 - 1955', '35 units', '3.0 L Lampredi V12', '217 hp @ 7000 rpm', '193 lb/ft @ 5000 rpm', 'N/A', '143 mph']
# ['1955 - 1957', '65 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '193 lb/ft @ 5000 rpm', '5.9 seconds', '125 mph']
# ['1957 - 1958', '50 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '193 lb/ft @ 5000 rpm', '5.9 seconds', '125 mph']
# ['1958 - 1960', '353 units', '3.0 L Colombo V1', '240 bhp @ 7000 rpm', '193 lb/ft @ 5000 rpm', '5.9 seconds', '125 mph']
# ['1956 - 1963', '77 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '193 lb/ft @ 5000 rpm', '5.2 seconds', '150 mph']
# ['1957 - 1959', '36 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '195 lb/ft @ 5000 rpm', '7.1 seconds', '149 mph']
# ['1958 - 1960', '50 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '195 lb/ft @ 5000 rpm', '6.5 seconds', '145 mph']
# ['1959 - 1962', '200 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '195 lb/ft @ 5000 rpm', '7.1 seconds', '149 mph']
# ['1960 - 1963', '58 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '195 lb/ft @ 5000 rpm', '6.5 seconds', '145 mph']
# ['1960 - 1963', '~1,000 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '181 lb/ft @ 5000 rpm', '8.0 seconds', '140 mph']
# ['1959', '7 units', '3.0 L Colombo V12', '240 bhp @ 7000 rpm', '193 lb/ft @ 5000 rpm', '5.2 seconds', '150mph']
# ['1960 - 1962', '176 (inc. racing)', '3.0 L Colombo V12', '240 hp @ 7,500 rpm', '215 lb/ft @ 5500 rpm', '5.2 seconds', '150 mph']
# ['1962 - 1964', '351 units', '3.0 L Colombo V12', '240 hp @ 7,500 rpm', '215 lb/ft @ 5500 rpm', '5.2 seconds', '150 mph']
# ['1962 - 1964', '36 units', '3.0 L Colombo V12', '302 bhp @ 7500 rpm', '246 lb/ft @ 5500 rpm', '5.4 seconds', '174 mph']
# ['1959 - 1962', '47 units (incl II)', '4.0 L Colombo V12', '340 bhp @ 7000 rpm', '235 lb/ft @ 4500 rpm', '~9.2 seconds', '174 mph']
# ['1962 - 1964', '47 units (incl I)', '4.0 L Colombo V12', '340 bhp @ 7000 rpm', '235 lb/ft @ 4500 rpm', '~9.2 seconds', '174 mph']
# ['1964 - 1966', '442 units', '3.3 L Colombo V12', '280 bhp @ 7600 rpm', '188 lb/ft @ 5500 rpm', '6.7 seconds', '145 mph']
# ['1964 - 1966', '200 units', '3.3 L Colombo V12', '260 bhp @ 7000 rpm', '202 lb/ft @ 5000 rpm', '7.2 seconds', '145 mph']
# ['1963 -1964', '50 units', '4.0 L Colombo V12', '295 bhp @ 6600 rpm', '240 lb/ft @ 5000 rpm', 'N/A', '142 mph']
# ['1964 - 1965', '1099 (I & II)', '4.0 L Colombo V12', '295 bhp @ 6600 rpm', '240 lb/ft @ 5000 rpm', 'N/A', '152 mph']
# ['1964 - 1967', '36 units', '5.0 L Colombo V12', '400 bhp @ 6500 rpm', 'N/A', 'N/A', '174 mph']
# ['1966 - 1968', '280 units', '3.3 L Colombo V12', '300hp @ 8,000 rpm', '232 lb/ft @ 6000 rpm', '5.5 seconds', '165 mph']
# ['1967', '10 units', '3.3 L Colombo V12', '300hp @ 8,000 rpm', '217 lb/ft @ 6000 rpm', '5.5 seconds', '155 mph']
# ['1966 - 1967', '1099 (I & II)', '4.0 L Colombo V12', '295 bhp @ 6600 rpm', '240 lb/ft @ 5000 rpm', 'N/A', '152 mph']
# ['1966 - 1968', '598 units', '4.0 L Colombo V12', '300 bhp @ 7000 rpm', '240 lb/ft @ 5000 rpm', '6.9 seconds', '152 mph']
# ['1966 - 1968', '100 units', '4.0 L Colombo V12', '300 bhp @ 7000 rpm', '240 lb/ft @ 5000 rpm', '6.9 seconds', '152 mph']
# ['1966 - 1967', '14 units', '4.4 L Colombo V12', '320 bhp @ 6600 rpm', '253 lb/ft @ 5000 rpm', '7.1 seconds', '152 mph']
# ['1967 - 1971', '800 units', '4.4 L Colombo V12', '320 bhp @ 6600 rpm', '308 lb/ft @ 5000 rpm', '7.1 seconds', '152 mph']
# ['1968 - 1973', '1,284 units', '4.4 L Colombo V12', '347 bhp @ 7500 rpm', '318 lb/ft @ 5500 rpm', '5.4 seconds', '173 mph']
# ['1968 - 1970', '168 units', '4.4 L Colombo V12', '320 bhp @ 7000 rpm', '240 lb/ft @ 2500 rpm', '6.9 seconds', '152 mph']
# ['1968 - 1970', '20 units', '4.4 L Colombo V12', '320 bhp @ 7000 rpm', '240 lb/ft @ 2500 rpm', '6.9 seconds', '152 mph']
# ['1971 - 1972', '505 units', '4.4 L Colombo V12', '340 bhp @ 6200 rpm', '318 lb/ft @ 4000 rpm', '6.7 seconds', '163 mph']
# ['1972 - 1976', '524 units', '4.4 L Nat Asp V12', '340 bhp @ 6200 rpm', '318 lb/ft @ 4000 rpm', '7.0 seconds', '163 mph']
# ['1976 - 1979', '355 units', '4.8 L Nat Asp V12', '340 bhp @ 7700 rpm', '347 lb/ft @ 3600 rpm', '7.1 seconds', '150 mph']
# ['1976 - 1979', '147 units', '4.8 L Nat Asp V12', '340 bhp @ 7700 rpm', '347 lb/ft @ 3600 rpm', '7.1 seconds', '150 mph']
# ['1979 - 1985', '422 units', '4.8 L Nat Asp V12', '306 bhp @ 6400 rpm', '289 lb/ft @ 4200 rpm', '8.3 seconds', '150 mph']
# ['1979 - 1985', '883 units', '4.8 L Nat Asp V12', '306 bhp @ 6400 rpm', '289 lb/ft @ 4200 rpm', '8.3 seconds', '150 mph']
# ['1985 - 1989', '270 (GT), 306 (A)', '4.9 L Nat Asp V12', '335 bhp @ 6000 rpm', '327 lb/ft @ 4200 rpm', '6.7 seconds', '155 mph']
# ['1968 - 1969', '152 units', '2.0 L Dino 65° V6', '180 bhp @ 8000 rpm', '137 lb/ft @ 6500 rpm', '7.5 seconds', '146 mph']
# ['1969 - 1974', '2,295 units', '2.4 L Dino 65° V6', '192 bhp @ 7600 rpm', '166 lb/ft @ 5500 rpm', '6.5 seconds', '146 mph']
# ['1972 - 1974', '1,274 units', '2.4 L Dino 65° V6', '192 bhp @ 7600 rpm', '166 lb/ft @ 5500 rpm', '6.5 seconds', '146 mph']
# ['1973 - 1975', 'N/A', '2.9 L Dino V8', '227 bhp @ 6600 rpm', '203 lb/ft @ 4600 rpm', 'N/A', '147 mph']
# ['1976 - 1980', 'N/A', '2.9 L Dino V8', '227 bhp @ 6600 rpm', '203 lb/ft @ 4600 rpm', 'N/A', '147 mph']
# ['1976 - 1980', 'N/A', '2.0 L Dino V8', '167 bhp @ 7700 rpm', '137 lb/ft @ 4900 rpm', 'N/A', '137 mph']
# ['1973 - 1976', '387 units', '4.4 L Nat Asp Flat-12', '339 bhp @ 7200 rpm', '335 lb/ft @ 6200 rpm', '5.4 seconds', '188 mph']
# ['1976 - 1981', '929 units', '4.9 L Nat Asp Flat-12', '360 bhp @ 6200 rpm', '332 lb/ft @ 4600 rpm', '5.5 seconds', '160 mph']
# ['1981 - 1984', '1,007 units', '4.9 L Nat Asp Flat-12', '340 bhp @ 6000 rpm', '332 lb/ft @ 4200 rpm', '5.4 seconds', '174 mph']
# ['1975 - 1977', '808 units', '2.9 L Nat Asp V8', '255 bhp @ 7500 rpm', '210 lb/ft @ 5000 rpm', '6.2 seconds', '155 mph']
# ['1975 - 1980', '2,185 units', '2.9 L Nat Asp V8', '255 bhp @ 7500 rpm', '210 lb/ft @ 5000 rpm', '6.2 seconds', '155 mph']
# ['1977 - 1980', '3,219 units', '2.9 L Nat Asp V8', '255 bhp @ 7500 rpm', '210 lb/ft @ 5000 rpm', '6.2 seconds', '155 mph']
# ['1980 - 1981', '160 units', '2.0 L Nat Asp V8', '153 bhp @ 6800 rpm', '125 lb/ft @ 4200 rpm', '6.8 seconds', '134 mph']
# ['1980 - 1981', '140 units', '2.0 L Nat Asp V8', '153 bhp @ 6800 rpm', '125 lb/ft @ 4200 rpm', '6.8 seconds', '134 mph']
# ['1980 - 1983', '494 units', '2.9 L Nat Asp V8', '214 bhp @ 6600 rpm', '179 lb/ft @ 4600 rpm', 'N/A', '149 mph']
# ['1980 - 1983', '1,743 units', '2.9 L Nat Asp V8', '214 bhp @ 6600 rpm', '179 lb/ft @ 4600 rpm', 'N/A', '149 mph']
# ['1982 - 1985', '437 units', '2.0 L Turbo V8', '217 bhp @ 7000 rpm', '177 lb/ft @ 4800 rpm', '6.6 seconds', '150 mph']
# ['1982 - 1985', '250 units', '2.0 L Turbo V8', '217 bhp @ 7000 rpm', '177 lb/ft @ 4800 rpm', '6.6 seconds', '150 mph']
# ['1982 - 1985', '748 units', '2.9 L Nat Asp V8', '237 bhp @ 7000 rpm', '191 lb/ft @ 5000 rpm', '6.7 seconds', '156 mph']
# ['1982 - 1985', '3,042 units', '2.9 L Nat Asp V8', '237 bhp @ 7000 rpm', '191 lb/ft @ 5000 rpm', '6.7 seconds', '156 mph']
# ['1984 - 1987', '272 units', '2.9L twin-turbo V8', '394 bhp @ 7,000 rpm', '366 lb/ft @ 3800 rpm', '4.8 seconds', '189 mph']
# ['1986 - 1989', '1,344 units', '3.2 L Nat Asp V8', '270 bhp @ 7000 rpm', '231 lb/ft @ 5500 rpm', '5.5 seconds', '166 mph']
# ['1986 - 1989', '6,068 units', '3.2 L Nat Asp V8', '270 bhp @ 7000 rpm', '231 lb/ft @ 5500 rpm', '5.5 seconds', '166 mph']
# ['1986 - 1989', 'N/A', '2.0 L Turbo V8', '251 bhp @ 6500 rpm', '242 lb/ft @ 4100 rpm', '6.3 seconds', '157 mph']
# ['1986 - 1989', 'N/A', '2.0 L Turbo V8', '251 bhp @ 6500 rpm', '242 lb/ft @ 4100 rpm', '6.3 seconds', '157 mph']
# ['1981 - 1982', '703 units', '3.0 L Nat Asp V8', '214 bhp @ 6600 rpm', '181 lb/ft @ 4600 rpm', '9.4 seconds', '143 mph']
# ['1982 - 1985', '1145 units', '3.0 L Nat Asp V8', '237 bhp @ 7000 rpm', '191 lb/ft @ 5000 rpm', '7.4 seconds', '150 mph']
# ['1983 - 1985', '629 units', '3.0 L Nat Asp V8', '237 bhp @ 7000 rpm', '191 lb/ft @ 5000 rpm', '7.4 seconds', '150 mph']
# ['1985 - 1988', '987 units', '3.2 L Nat Asp V8', '270 bhp @ 7000 rpm', '224 lb/ft @ 5500 rpm', '7.4 seconds', '155 mph']
# ['1985 - 1988', '810 units', '3.2 L Nat Asp V8', '270 bhp @ 7000 rpm', '224 lb/ft @ 5500 rpm', '7.4 seconds', '155 mph']
# ['1989 - 1993', '858 units', '3.4 L Nat Asp V8', '300 bhp @ 7200 rpm', '238 lb/ft @ 4200 rpm', '6.6 seconds', '159 mph']
# ['1989 - 1993', '1,017 units', '3.4 L Nat Asp V8', '300 bhp @ 7200 rpm', '238 lb/ft @ 4200 rpm', '6.6 seconds', '159 mph']
# ['1984 - 1991', '7,177 units', '4.9 L Nat Asp Flat-12', '385 bhp @ 6,300 rpm', '361 lb/ft @ 4500 rpm', '5.8 seconds', '180 mph']
# ['1991 - 1994', '2,261 units', '4.9 L Nat Asp Flat-12', '422 bhp @ 6750 rpm', '362 lb/ft @ 5500 rpm', '4.8 seconds', '195 mph']
# ['1994 - 1996', '501 units', '4.9 L Nat Asp Flat-12', '434 bhp @ 6,750 rpm', '370 lb/ft @ 5500 rpm', '4.7 seconds', '196 mph']
# ['1989 - 1993', '2,895 units', '3.4 L Nat Asp V8', '296 bhp @ 7200 rpm', '238 lb/ft @ 4200 rpm', '6.0 seconds', '166 mph']
# ['1989 - 1993', '4,230 units', '3.4 L Nat Asp V8', '296 bhp @ 7200 rpm', '238 lb/ft @ 4200 rpm', '46.0 seconds', '166 mph']
# ['1993 - 1995', '252 units', '3.4 L Nat Asp V8', '316 bhp @ 7200 rpm', '238 lb/ft @ 4200 rpm', '5.4 seconds', '174 mph']
# ['1993 - 1995', '137 units', '3.4 L Nat Asp V8', '316 bhp @ 7200 rpm', '238 lb/ft @ 4200 rpm', '5.4 seconds', '174 mph']
# ['1993 - 1995', '1,090 units', '3.4 L Nat Asp V8', '316 bhp @ 7200 rpm', '238 lb/ft @ 4200 rpm', '5.4 seconds', '174 mph']
# ['1992 - 1993', '100 units', '3.4 L Nat Asp V8', '312 bhp @ 7,200 rpm', '238 lb/ft @ 4200 rpm', '5.3 seconds', '171 mph']
# ['1994 - 1999', '3,829 units', '3.5 L Nat Asp V8', '375 bhp @ 8,250 rpm', '268 lb/ft @ 6000 rpm', '4.7 seconds', '183 mph']
# ['1995 - 1999', '2,577 units', '3.5 L Nat Asp V8', '375 bhp @ 8,250 rpm', '268 lb/ft @ 6000 rpm', '4.7 seconds', '183 mph']
# ['1996 - 1999', '2,690 units', '3.5 L Nat Asp V8', '375 bhp @ 8,250 rpm', '268 lb/ft @ 6000 rpm', '4.7 seconds', '175 mph']
# ['1997 - 1999', '1,042 units', '3.5 L Nat Asp V8', '375 bhp @ 8,250 rpm', '268 lb/ft @ 6000 rpm', '4.7 seconds', '183 mph']
# ['1997 - 1999', '529 units', '3.5 L Nat Asp V8', '375 bhp @ 8,250 rpm', '268 lb/ft @ 6000 rpm', '4.7 seconds', '183 mph']
# ['1997 - 1999', '1,127 units', '3.5 L Nat Asp V8', '375 bhp @ 8,250 rpm', '268 lb/ft @ 6000 rpm', '4.7 seconds', '175 mph']
# ['1992 - 1997', '1,548 units', '5.5 L Nat Asp V12', '436 bhp @ 4500 rpm', '406 lb/ft @ 4250 rpm', '5.2 seconds', '186 mph']
# ['1993 - 1997', '403 units', '5.5 L Nat Asp V12', '436 bhp @ 4500 rpm', '406 lb/ft @ 4250 rpm', '5.2 seconds', '186 mph']
# ['1998 - 2003', '688 units', '5.5 L Nat Asp V12', '442 bhp @ 6250 rpm', '406 lb/ft @ 4500 rpm', '5.0 seconds', '186 mph']
# ['1998 - 2003', '650 units', '5.5 L Nat Asp V12', '442 bhp @ 6250 rpm', '406 lb/ft @ 4500 rpm', '5.0 seconds', '186 mph']
# ['2002 - 2003', '30 units', '5.5 L Nat Asp V12', '442 bhp @ 6250 rpm', '406 lb/ft @ 4500 rpm', '5.0 seconds', '186 mph']
# ['1996 - 2002', '3,083 units', '5.5 L Nat Asp V12', '478 bhp @ 7,000 rpm', '419 lb/ft @ 5000 rpm', '4.4 seconds', '199 mph']
# ['2001', '448 units', '5.5 L Nat Asp V12', '478 bhp @ 7,000 rpm', '419 lb/ft @ 5000 rpm', '4.4 seconds', '186 mph']
# ['2002 - 2006', '2,056 units', '5.7 L Nat Asp V12', '508 bhp @ 7,250 rpm', '434 lb/ft @ 5250 rpm', '4.2 seconds', '202 mph']
# ['2004 - 2010', '3,025 units', '5.7 L Nat Asp V12', '533 bhp @ 7250 rpm', '434 lb/ft @ 5250 rpm', '4.0 seconds', '199 mph']
# ['1999 - 2005', '8,800 units', '3.6 L Nat Asp V8', '395 bhp @ 8500 rpm', '275 lb/ft @ 4750 rpm', '4.3 seconds', '189 mph']
# ['2001 - 2005', '7,565 units', '3.6 L Nat Asp V8', '395 bhp @ 8500 rpm', '275 lb/ft @ 4750 rpm', '4.5 seconds', '180 mph']
# ['2003 - 2004', '1,288 units', '3.6 L Nat Asp V8', '420 bhp @ 8500 rpm', '275 lb/ft @ 4750 rpm', '3.8 seconds', '186 mph']
# ['2005 - 2009', '~6,280 units', '4.3 L Nat Asp V8', '483 bhp @ 8500 rpm', '299 lb/ft @ 5250 rpm', '3.6 seconds', '196 mph']
# ['2006 - 2009', '~7,720 units', '4.3 L Nat Asp V8', '483 bhp @ 8500 rpm', '299 lb/ft @ 5250 rpm', '3.6 seconds', '193 mph']
# ['2007 - 2010', '~2,500 units', '4.3 L Nat Asp V8', '503 bhp @ 8500 rpm', '347 lb/ft @ 5250 rpm', '3.6 seconds', '198 mph']
# ['2009 - 2010', '~499 units', '4.3 L Nat Asp V8', '503 bhp @ 8500 rpm', '347 lb/ft @ 5250 rpm', '3.6 seconds', '198 mph']
# ['2006 - 2012', '~4,000 units', '6.0 L Nat Asp V12', '612 bhp @ 7600 rpm', '448 lb/ft @ 5600 rpm', '3.2 seconds', '205 mph']
# ['2010 - 2012', '599 units', '6.0 L Nat Asp V12', '661 bhp @ 8250 rpm', '457 lb/ft @ 6500 rpm', '3.3 seconds', '208 mph']
# ['2010', '80 units', '6.0 L Nat Asp V12', '661 bhp @ 8250 rpm', '457 lb/ft @ 6500 rpm', '3.6 seconds', '202 mph']
# ['2009 - 2012', 'N/A', '4.3 L Nat Asp V8', '453 bhp @ 7750 rpm', '358 lb/ft @ 5000 rpm', '4.0 seconds', '193 mph']
# ['2012 - 2014', 'N/A', '4.3 L Nat Asp V8', '483 bhp @ 7750 rpm', '372 lb/ft @ 5000 rpm', '3.8 seconds', '194 mph']
# ['2015 - 2017', 'N/A', '3.9 L twin-turbo V8', '553 hp @ 7500 rpm', '557 lb/ft @ 4750 rpm', '3.6 seconds', '196 mph']
# ['2010 - 2015', 'N/A', '4.5 L Nat Asp V8', '562 hp @ 9000 rpm', '394 lb/ft @ 6000 rpm', '3.3 seconds', '202 mph']
# ['2011 - 2015', 'N/A', '4.5 L Nat Asp V8', '562 hp @ 9000 rpm', '398 lb/ft @ 6000 rpm', '3.3 seconds', '202 mph']
# ['2013 - 2015', '~3,000 units', '4.5 L Nat Asp V8', '597 bhp @ 9000 rpm', '398 lb/ft @ 6000 rpm', '3.0 seconds', '202 mph']
# ['2014 - 2015', '499 units', '4.5 L Nat Asp V8', '597 bhp @ 9000 rpm', '398 lb/ft @ 6000 rpm', '3.0 seconds', '202 mph']
# ['2012', '20 units', '4.5 L Nat Asp V8', '562 hp @ 9000 rpm', '398 lb/ft @ 6000 rpm', '3.3 seconds', '202 mph']
# ['2011 - 2016', 'N/A', '6.3 L Nat Asp V12', '650 hp @ 8000 rpm', '504 lb/ft @ 6000 rpm', '3.7 seconds', '208 mph']
# ['2016 - 2020', 'N/A', '6.3 L Nat Asp V12', '681 bhp @ 8000 rpm', '516 lb/ft @ 5750 rpm', '3.4 seconds', '208 mph']
# ['2017 - 2020', 'N/A', '3.9 L twin-turbo V8', '602 bhp @ 7500 rpm', '561 lb/ft @ 3000 rpm', '3.5 seconds', '199 mph']
# ['2012 - 2017', 'N/A', '6.3 L Nat Asp V12', '730 bhp @ 8250 rpm', '509 lb/ft @ 6000 rpm', '3.1 seconds', '211 mph']
# ['2015 - 2017', '799 units', '6.3 L Nat Asp V12', '769 bhp @ 8500 rpm', '520 lb/ft @ 6750 rpm', '2.9 seconds', '211 mph']
# ['2015 - 2019', 'N/A', '3.9 L twin-turbo V8', '661 bhp @ 8000 rpm', '561 lb/ft @ 3000 rpm', '3.0 seconds', '205 mph']
# ['2016 - 2019', 'N/A', '3.9 L twin-turbo V8', '661 bhp @ 8000 rpm', '561 lb/ft @ 3000 rpm', '3.0 seconds', '202 mph']
# ['2018 - 2020', 'N/A', '3.9L twin-turbo V8', '710 bhp @ 8000 rpm', '568 lb/ft @ 3000 rpm', '2.85 seconds', '211 mph']
# ['2018 - 2020', 'N/A', '3.9 L twin-turbo V8', '710 bhp @ 8000 rpm', '568 lb/ft @ 3000 rpm', '2.85 seconds', '211 mph']
# ['2020', 'N/A', '3.9 L twin-turbo V8', '710 bhp @ 8000 rpm', '568 lb/ft @ 3000 rpm', '2.85 seconds', '211 mph']
# ['2017 - 2020', 'N/A', '3.9 L twin-turbo V8', '591 bhp @ 7500 rpm', '560 lb/ft @ 3000 rpm', '3.5 seconds', '199 mph']
# ['US$340,712', '6.5L naturally aspirated V12', '789 hp @ 8500 rpm', '530 lb-ft @ 7000 rpm', '2.8 s', '7.9 s', '211 mph']
# ['US$401,000', '6.5L naturally aspirated V12', '789 hp @ 8900 rpm', '530 lb-ft @ 7000 rpm', '2.9 s', '8.3 s', '211 mph']
# ['1962 - 1964', '36', 'Tipo 168/62 V12', '302 hp @ 7,500 rpm', '217 lb-ft @ 5,500 rpm', '6.1 seconds', '177 mph']
# ['1984 - 1987', '272', '2.9L twin-turbo V8', '394 bhp @ 7,000 rpm', '366 lb-ft @ 3,800 rpm', '4.8 seconds', '189 mph']
# ['1987 - 1992', '1,315', '2.9L twin-turbo V8', '478 bhp @ 7000 rpm', '425 lb-ft @ 4,000 rpm', '3.8 seconds', '201 mph']
# ['1995 - 1997', '349', '4.7L Tipo F130B V12', '513 hp @ 8,500 rpm', '347 lb-ft @ 6,500 rpm', '3.7 seconds', '202 mph']
# ['2002 - 2004', '400', '6.0L Tipo F140B V12', '660 hp @ 7,800 rpm', '485 lb-ft @ 5,500 rpm', '3.1 seconds', '217 mph']
# ['2013-2018 (inc. Aperta)', '499, 210 (Aperta)', '6.3L V12 + Electric', '950 bhp @ 9000rpm', '664 lb-ft', '2.7 seconds', '217+ mph']

# %%
df2
# Out:
#                        Years         Production               Engine  \
# 0                1948 - 1950           38 units    2.0 L Colombo V12
# 1                1950 - 1951           28 units    2.3 L Colombo V12
# 2                1951 - 1952           82 units    2.6 L Colombo V12
# 3                1951 - 1952           27 units    2.6 L Colombo V12
# 4                       1952           23 units   4.1 L Lampredi V12
# ..                       ...                ...                  ...
# 136              1984 - 1987                272   2.9L twin-turbo V8
# 137              1987 - 1992              1,315   2.9L twin-turbo V8
# 138              1995 - 1997                349  4.7L Tipo F130B V12
# 139              2002 - 2004                400  6.0L Tipo F140B V12
# 140  2013-2018 (inc. Aperta)  499, 210 (Aperta)  6.3L V12 + Electric
#
#                    Power                 Torque      0-60 mph Top Speed
# 0    110 bhp @ 6,000 rpm                    N/A           N/A   106 mph
# 1     130 bhp @ 6000 rpm                    N/A           N/A   112 mph
# 2     150 bhp @ 6500 rpm                    N/A           N/A   112 mph
# 3     150 bhp @ 6500 rpm                    N/A  ~9.0 seconds   115 mph
# 4     200 bhp @ 5000 rpm                    N/A           N/A   116 mph
# ..                   ...                    ...           ...       ...
# 136  394 bhp @ 7,000 rpm  366 lb-ft @ 3,800 rpm   4.8 seconds   189 mph
# 137   478 bhp @ 7000 rpm  425 lb-ft @ 4,000 rpm   3.8 seconds   201 mph
# 138   513 hp @ 8,500 rpm  347 lb-ft @ 6,500 rpm   3.7 seconds   202 mph
# 139   660 hp @ 7,800 rpm  485 lb-ft @ 5,500 rpm   3.1 seconds   217 mph
# 140    950 bhp @ 9000rpm              664 lb-ft   2.7 seconds  217+ mph
#
# [141 rows x 7 columns]

# %%
df2.insert(0, "Model Name", legacy_model_names, True)
df2.insert(1, "More Info", legacy_model_links, True)

# %%
df2
# Out:
#               Model Name                                          More Info  \
# 0      Ferrari 166 Inter  https://www.supercars.net/blog/category/brand/...
# 1      Ferrari 195 Inter  https://www.supercars.net/blog/category/brand/...
# 2      Ferrari 212 Inter  https://www.supercars.net/blog/category/brand/...
# 3     Ferrari 212 Export  https://www.supercars.net/blog/category/brand/...
# 4    Ferrari 342 America  https://www.supercars.net/blog/category/brand/...
# ..                   ...                                                ...
# 136      Ferrari 288 GTO  https://www.supercars.net/blog/category/brand/...
# 137          Ferrari F40  https://www.supercars.net/blog/category/brand/...
# 138          Ferrari F50  https://www.supercars.net/blog/category/brand/...
# 139         Ferrari Enzo  https://www.supercars.net/blog/category/brand/...
# 140    Ferrari LaFerrari  https://www.supercars.net/blog/category/brand/...
#
#                        Years         Production               Engine  \
# 0                1948 - 1950           38 units    2.0 L Colombo V12
# 1                1950 - 1951           28 units    2.3 L Colombo V12
# 2                1951 - 1952           82 units    2.6 L Colombo V12
# 3                1951 - 1952           27 units    2.6 L Colombo V12
# 4                       1952           23 units   4.1 L Lampredi V12
# ..                       ...                ...                  ...
# 136              1984 - 1987                272   2.9L twin-turbo V8
# 137              1987 - 1992              1,315   2.9L twin-turbo V8
# 138              1995 - 1997                349  4.7L Tipo F130B V12
# 139              2002 - 2004                400  6.0L Tipo F140B V12
# 140  2013-2018 (inc. Aperta)  499, 210 (Aperta)  6.3L V12 + Electric
#
#                    Power                 Torque      0-60 mph Top Speed
# 0    110 bhp @ 6,000 rpm                    N/A           N/A   106 mph
# 1     130 bhp @ 6000 rpm                    N/A           N/A   112 mph
# 2     150 bhp @ 6500 rpm                    N/A           N/A   112 mph
# 3     150 bhp @ 6500 rpm                    N/A  ~9.0 seconds   115 mph
# 4     200 bhp @ 5000 rpm                    N/A           N/A   116 mph
# ..                   ...                    ...           ...       ...
# 136  394 bhp @ 7,000 rpm  366 lb-ft @ 3,800 rpm   4.8 seconds   189 mph
# 137   478 bhp @ 7000 rpm  425 lb-ft @ 4,000 rpm   3.8 seconds   201 mph
# 138   513 hp @ 8,500 rpm  347 lb-ft @ 6,500 rpm   3.7 seconds   202 mph
# 139   660 hp @ 7,800 rpm  485 lb-ft @ 5,500 rpm   3.1 seconds   217 mph
# 140    950 bhp @ 9000rpm              664 lb-ft   2.7 seconds  217+ mph
#
# [141 rows x 9 columns]

# %%
df2.to_csv(r'C:\Users\dawid\Python Outputs\legacy_ferrari_models.csv')
